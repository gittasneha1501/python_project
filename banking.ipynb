# %%
class BankAccount:
    def __init__(self, name, balance=500):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} into {self.name}'s account.")
        else:
            print("Invalid amount")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} from {self.name}'s account.")
        else:
            print("Insufficient funds")

    def check_balance(self):
        print(f"{self.name}'s balance: {self.balance}")

def main():
    accounts = {}

    while True:
        print("vamsi international bank")
        print("1. Create an account")
        print("2. Deposit money")
        print("3. Withdraw money")
        print("4. Check balance")
        print("5. Exit")

        choice = input("Enter a number: ")
        if choice == '1':
          name = input("Enter account holder's name: ")
          mobile = int(input('enter mobile no:'))
          accounts[name] = BankAccount(name)
          print(f"Account for {name} with mobile_no {mobile} created successfully.")

        elif choice == '2':
            if name in accounts:
                amount = float(input("Enter amount to deposit: "))
                accounts[name].deposit(amount)
            else:
                print("Account not found.")

        elif choice == '3':
            if name in accounts:
                amount = float(input("Enter amount to withdraw: "))
                accounts[name].withdraw(amount)
            else:
                print("Account not found.")

        elif choice == '4':
            if name in accounts:
              accounts[name].check_balance()
            else:
                print("Account not found.")

        elif choice == '5':
            print("Thank you for banking with us!")
            break

        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

if __name__=='__main__':
   main()
# Out:
# vamsi international bank
# 1. Create an account
# 2. Deposit money
# 3. Withdraw money
# 4. Check balance
# 5. Exit
# Enter a number: 1
# Enter account holder's name: sneha
# enter mobile no:8328239954
# Account for sneha with mobile_no 8328239954 created successfully.
# vamsi international bank
# 1. Create an account
# 2. Deposit money
# 3. Withdraw money
# 4. Check balance
# 5. Exit
# Enter a number: 2
# Enter amount to deposit: 200
# Deposited 200.0 into sneha's account.
# vamsi international bank
# 1. Create an account
# 2. Deposit money
# 3. Withdraw money
# 4. Check balance
# 5. Exit
# Enter a number: 3
# Enter amount to withdraw: 200
# Withdrew 200.0 from sneha's account.
# vamsi international bank
# 1. Create an account
# 2. Deposit money
# 3. Withdraw money
# 4. Check balance
# 5. Exit
# Enter a number: 4
# sneha's balance: 500.0
# vamsi international bank
# 1. Create an account
# 2. Deposit money
# 3. Withdraw money
# 4. Check balance
# 5. Exit
# Enter a number: 5
# Thank you for banking with us!
